# %%
import pandas as pd

# Load baseline HR data
baseline_hr = pd.read_csv('/Users/urmebose/Desktop/MF/Nuro/hr.csv')

# Load HR data for all three seasons
hr_01 = pd.read_csv('/Users/urmebose/Desktop/DM/hr_01.csv')
hr_02 = pd.read_csv('/Users/urmebose/Desktop/DM/hr_02.csv')
hr_03 = pd.read_csv('/Users/urmebose/Desktop/DM/hr_03.csv')

# Function to clean HR data
def clean_hr_data(hr_data):
    hr_data_clean = hr_data[hr_data['confidence'] > 0]  # Filter out low-confidence measurements
    return hr_data_clean

# Clean the HR data
baseline_hr_clean = clean_hr_data(baseline_hr)
hr_01_clean = clean_hr_data(hr_01)
hr_02_clean = clean_hr_data(hr_02)
hr_03_clean = clean_hr_data(hr_03)

# Calculate average heart rate for baseline and each season
baseline_avg_hr = baseline_hr_clean['heart_rate'].mean()
avg_hr_01 = hr_01_clean['heart_rate'].mean()
avg_hr_02 = hr_02_clean['heart_rate'].mean()
avg_hr_03 = hr_03_clean['heart_rate'].mean()

# Calculate the difference between the baseline and each season's average HR
hr_difference_01 = avg_hr_01 - baseline_avg_hr
hr_difference_02 = avg_hr_02 - baseline_avg_hr
hr_difference_03 = avg_hr_03 - baseline_avg_hr

# Display the results
print(f'Baseline Average HR: {baseline_avg_hr:.2f} BPM')
print(f'Season 1 Average HR: {avg_hr_01:.2f} BPM')
print(f'Difference from Baseline in Season 1: {hr_difference_01:.2f} BPM')
print(f'Season 2 Average HR: {avg_hr_02:.2f} BPM')
print(f'Difference from Baseline in Season 2: {hr_difference_02:.2f} BPM')
print(f'Season 3 Average HR: {avg_hr_03:.2f} BPM')
print(f'Difference from Baseline in Season 3: {hr_difference_03:.2f} BPM')
# Out:
# Baseline Average HR: 84.85 BPM
# Season 1 Average HR: 96.01 BPM
# Difference from Baseline in Season 1: 11.16 BPM
# Season 2 Average HR: 92.43 BPM
# Difference from Baseline in Season 2: 7.58 BPM
# Season 3 Average HR: 93.38 BPM
# Difference from Baseline in Season 3: 8.53 BPM

# %%
import pandas as pd

# Load baseline HR data
baseline_hr = pd.read_csv('/Users/urmebose/Desktop/MF/Nuro/hr.csv')

# Load HR data for all three seasons
hr_01 = pd.read_csv('/Users/urmebose/Desktop/DM/hr_01.csv')
hr_02 = pd.read_csv('/Users/urmebose/Desktop/DM/hr_02.csv')
hr_03 = pd.read_csv('/Users/urmebose/Desktop/DM/hr_03.csv')

# Function to clean HR data
def clean_hr_data(hr_data):
    hr_data_clean = hr_data[hr_data['confidence'] > 0]  # Filter out low-confidence measurements
    return hr_data_clean

# Clean the HR data
baseline_hr_clean = clean_hr_data(baseline_hr)
hr_01_clean = clean_hr_data(hr_01)
hr_02_clean = clean_hr_data(hr_02)
hr_03_clean = clean_hr_data(hr_03)

# Calculate average heart rate for baseline and each season
baseline_avg_hr = baseline_hr_clean['heart_rate'].mean()
avg_hr_01 = hr_01_clean['heart_rate'].mean()
avg_hr_02 = hr_02_clean['heart_rate'].mean()
avg_hr_03 = hr_03_clean['heart_rate'].mean()

# Calculate the difference between the baseline and each season's average HR
hr_difference_01 = avg_hr_01 - baseline_avg_hr
hr_difference_02 = avg_hr_02 - baseline_avg_hr
hr_difference_03 = avg_hr_03 - baseline_avg_hr

# Define anxiety threshold
hr_anxiety_threshold = 90

# Determine if the average HR for each season indicates anxiety
anxiety_hr_baseline = baseline_avg_hr > hr_anxiety_threshold
anxiety_hr_01 = avg_hr_01 > hr_anxiety_threshold
anxiety_hr_02 = avg_hr_02 > hr_anxiety_threshold
anxiety_hr_03 = avg_hr_03 > hr_anxiety_threshold

# Display the results
print(f'Baseline Average HR: {baseline_avg_hr:.2f} BPM - {"Anxiety" if anxiety_hr_baseline else "Normal"}')
print(f'Season 1 Average HR: {avg_hr_01:.2f} BPM - {"Anxiety" if anxiety_hr_01 else "Normal"}')
print(f'Difference from Baseline in Season 1: {hr_difference_01:.2f} BPM')
print(f'Season 2 Average HR: {avg_hr_02:.2f} BPM - {"Anxiety" if anxiety_hr_02 else "Normal"}')
print(f'Difference from Baseline in Season 2: {hr_difference_02:.2f} BPM')
print(f'Season 3 Average HR: {avg_hr_03:.2f} BPM - {"Anxiety" if anxiety_hr_03 else "Normal"}')
print(f'Difference from Baseline in Season 3: {hr_difference_03:.2f} BPM')
# Out:
# Baseline Average HR: 84.85 BPM - Normal
# Season 1 Average HR: 96.01 BPM - Anxiety
# Difference from Baseline in Season 1: 11.16 BPM
# Season 2 Average HR: 92.43 BPM - Anxiety
# Difference from Baseline in Season 2: 7.58 BPM
# Season 3 Average HR: 93.38 BPM - Anxiety
# Difference from Baseline in Season 3: 8.53 BPM

# %%
import numpy as np

# Load IBI data for baseline and all three seasons
baseline_ibi = pd.read_csv('//Users/urmebose/Desktop/DM/ibi.csv')
ibi_01 = pd.read_csv('/Users/urmebose/Desktop/DM/ibi_01.csv')
ibi_02 = pd.read_csv('/Users/urmebose/Desktop/DM/ibi_02.csv')
ibi_03 = pd.read_csv('/Users/urmebose/Desktop/DM/ibi_03.csv')

# Clean the IBI data
def clean_ibi_data(ibi_data):
    ibi_data_clean = ibi_data[ibi_data['ibi'] > 0]  # Filter out invalid IBI values
    return ibi_data_clean

baseline_ibi_clean = clean_ibi_data(baseline_ibi)
ibi_01_clean = clean_ibi_data(ibi_01)
ibi_02_clean = clean_ibi_data(ibi_02)
ibi_03_clean = clean_ibi_data(ibi_03)

# Function to calculate RMSSD
def calculate_rmssd(ibi_values):
    diff_nn_intervals = np.diff(ibi_values)
    squared_diffs = diff_nn_intervals ** 2
    rmssd = np.sqrt(np.mean(squared_diffs))
    return rmssd

# Function to calculate SDNN
def calculate_sdnn(ibi_values):
    sdnn = np.std(ibi_values, ddof=1)
    return sdnn

# Calculate RMSSD and SDNN for baseline and each season
rmssd_baseline = calculate_rmssd(baseline_ibi_clean['ibi'].dropna().values)
sdnn_baseline = calculate_sdnn(baseline_ibi_clean['ibi'].dropna().values)

rmssd_01 = calculate_rmssd(ibi_01_clean['ibi'].dropna().values)
sdnn_01 = calculate_sdnn(ibi_01_clean['ibi'].dropna().values)

rmssd_02 = calculate_rmssd(ibi_02_clean['ibi'].dropna().values)
sdnn_02 = calculate_sdnn(ibi_02_clean['ibi'].dropna().values)

rmssd_03 = calculate_rmssd(ibi_03_clean['ibi'].dropna().values)
sdnn_03 = calculate_sdnn(ibi_03_clean['ibi'].dropna().values)

# Display HRV metrics
print(f'Baseline RMSSD: {rmssd_baseline:.2f} ms, SDNN: {sdnn_baseline:.2f} ms')
print(f'Season 1 RMSSD: {rmssd_01:.2f} ms, SDNN: {sdnn_01:.2f} ms')
print(f'Season 2 RMSSD: {rmssd_02:.2f} ms, SDNN: {sdnn_02:.2f} ms')
print(f'Season 3 RMSSD: {rmssd_03:.2f} ms, SDNN: {sdnn_03:.2f} ms')

# Define anxiety thresholds
rmssd_threshold = 20
sdnn_threshold = 50

# Determine if the HRV metrics indicate anxiety
anxiety_rmssd_baseline = rmssd_baseline < rmssd_threshold
anxiety_sdnn_baseline = sdnn_baseline < sdnn_threshold

anxiety_rmssd_01 = rmssd_01 < rmssd_threshold
anxiety_sdnn_01 = sdnn_01 < sdnn_threshold

anxiety_rmssd_02 = rmssd_02 < rmssd_threshold
anxiety_sdnn_02 = sdnn_02 < sdnn_threshold

anxiety_rmssd_03 = rmssd_03 < rmssd_threshold
anxiety_sdnn_03 = sdnn_03 < sdnn_threshold

# Display the anxiety determination
print(f'Baseline RMSSD Anxiety: {"Yes" if anxiety_rmssd_baseline else "No"}, SDNN Anxiety: {"Yes" if anxiety_sdnn_baseline else "No"}')
print(f'Season 1 RMSSD Anxiety: {"Yes" if anxiety_rmssd_01 else "No"}, SDNN Anxiety: {"Yes" if anxiety_sdnn_01 else "No"}')
print(f'Season 2 RMSSD Anxiety: {"Yes" if anxiety_rmssd_02 else "No"}, SDNN Anxiety: {"Yes" if anxiety_sdnn_02 else "No"}')
print(f'Season 3 RMSSD Anxiety: {"Yes" if anxiety_rmssd_03 else "No"}, SDNN Anxiety: {"Yes" if anxiety_sdnn_03 else "No"}')
# Out:
# Baseline RMSSD: 30.08 ms, SDNN: 28.63 ms
# Season 1 RMSSD: 42.83 ms, SDNN: 36.23 ms
# Season 2 RMSSD: 26.76 ms, SDNN: 29.91 ms
# Season 3 RMSSD: 36.53 ms, SDNN: 30.75 ms
# Baseline RMSSD Anxiety: No, SDNN Anxiety: Yes
# Season 1 RMSSD Anxiety: No, SDNN Anxiety: Yes
# Season 2 RMSSD Anxiety: No, SDNN Anxiety: Yes
# Season 3 RMSSD Anxiety: No, SDNN Anxiety: Yes
